# %% [markdown]
# Connected to lo_optim2 (Python 3.11.14)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import jax.numpy as jnp
import jax

jax.config.update("jax_enable_x64", True)
# jax.config.update('jax_default_device', jax.devices('cpu')[0])

# Import your optimization and plotting utilities
from optimization_core import (
    build_jsa_grid,
    run_penalty_only,
    run_trust_only,
    save_results,
    load_results,
    plot_2d_projection,
    plot_modes,
    plot_init_mode,
    plot_all_amplitudes,
    plot_constraint_violation,
    plot_final_objective,
    plot_outer_iterations,
    plot_outer_objective_both_seeds,
)

# ---------------------------------------------------------
# 1. Experiment parameters
# ---------------------------------------------------------

# Parameters for the multivariate normal distribution
n = 60  # Number of points in the frequency grid nxnxn
d = 4  # Dimensionality of the problem
mean = jnp.zeros(d)  # Mean
x_lim = 4  # Limits in x and y ax0is for plotting
rho_value = 0.96  # Correlation coefficient

filename = f"penalty_results_{d}D_20260303.pkl"

seed_init = 12345
K = 1  # Number of random seeds for optimization runs (for both methods)

bh_kwargs = {"n_iter": 500, "displ": True}

lambda0 = 1e-2
lambda_factor = 2
tol_constraint = 1e-6
max_outer_iters = 40
max_inner_iters = 500

params = {
    "n": n,
    "mean": mean,
    "x_lim": x_lim,
    "rho_value": rho_value,
    "seed_init": seed_init,
    "K": K,
    "bh_kwargs": bh_kwargs,
    "lambda0": lambda0,
    "lambda_factor": lambda_factor,
    "tol_constraint": tol_constraint,
    "max_outer_iters": max_outer_iters,
    "max_inner_iters": max_inner_iters,
}

# ---------------------------------------------------------
# 2. Build JSA grid and initial mode
# ---------------------------------------------------------

print("Building JSA grid...")
jsa = build_jsa_grid(n=n, mean=mean, rho=rho_value, x_lim=x_lim)

# Initial seed (optimal)
_, jsa_data = build_jsa_grid(n, mean, rho_value, x_lim)
jsa_flat = jnp.reshape(jsa_data, (n, n ** (d - 1)))
u, s, vt = jax.scipy.linalg.svd(jsa_flat, full_matrices=False)

plot_2d_projection(jsa_data)
plot_modes(u, s, n_modes=8)

nv = 8
u_init = jnp.sum(u[:, :nv] / jnp.linalg.norm(u[:, :nv], axis=0), axis=1)
u_init_normal = u_init / jnp.linalg.norm(u_init)
f_init = jnp.concatenate([u_init_normal, jnp.zeros_like(u_init_normal)])
plot_init_mode(u_init, u[:, 0] / jnp.linalg.norm(u[:, 0]))

# ---------------------------------------------------------
# 3. Generate reproducible random seeds
# ---------------------------------------------------------


def generate_seeds(K, seed_init):
    rng = np.random.default_rng(seed_init)
    return rng.integers(0, 2**32 - 1, size=K)


seeds = generate_seeds(K, seed_init)

# ---------------------------------------------------------
# 4. Run penalty-only (fast)
# ---------------------------------------------------------

# print("\nRunning penalty-only optimization...")
# df_pen = run_penalty_only(
#     f_opt_init=f_init,
#     jsa=jsa_data,
#     seeds=seeds,
#     lambda0=lambda0,
#     lambda_factor=lambda_factor,
#     tol_constraint=tol_constraint,
#     max_outer_iters=max_outer_iters,
#     max_inner_iters=max_inner_iters,
# )


# save_results(df_pen, params, seeds, filename=filename)
# print("Penalty results saved.")

# ---------------------------------------------------------
# 5. Run trust-only (slow, can be done later)
# ---------------------------------------------------------

print("\nRunning trust-region optimization...")
df_trust = run_trust_only(
    f_opt_init=f_init,
    jsa=jsa_data,
    seeds=seeds,
    bh_kwargs=bh_kwargs,
)

save_results(df_trust, params, seeds, filename=f"trust_results_{d}D_20260304.pkl")
print("Trust-region results saved.")

# ---------------------------------------------------------
# 6. Load both and compare
# ---------------------------------------------------------

print("\nLoading saved results...")
# df_pen_loaded, params_loaded, seeds_loaded = load_results(filename)
df_trust_loaded, _, _ = load_results(f"trust_results_{d}D_20260304.pkl")


# ---------------------------------------------------------
# 7. Plots and data
# ---------------------------------------------------------
# df = pd.concat([df_pen_loaded, df_trust_loaded], ignore_index=True)
# df=df_pen_loaded
df = df_trust_loaded


def outer_converged(row):
    if row["outer_info"] is None:
        return None
    return row["outer_info"][-1]["converged"]


df["outer_converged"] = df.apply(outer_converged, axis=1)
# print(df[df["method"] == "penalty"][["method", "seed_type", "outer_converged"]])

print(
    df[df["method"] == "trust"][
        ["method", "seed_type", "trust_success", "trust_status", "trust_message"]
    ]
)

# plot_outer_iterations(df)
# plot_outer_objective_both_seeds(df)
plot_final_objective(df)
plot_constraint_violation(df)


# ---------------------------------------------------------
# 9. Plot amplitudes
# ---------------------------------------------------------

print("\nPlotting amplitudes...")
# plot_all_amplitudes(df_pen_loaded)
plot_all_amplitudes(df_trust_loaded)


print("\nExperiment complete.")
# Out:
# Building JSA grid...
# Running trust-region optimization...
# basinhopping step 0: f -0.485677
# basinhopping step 1: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# found new global minimum on step 1 with function value -0.485677
# basinhopping step 2: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 3: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# found new global minimum on step 3 with function value -0.485677
# basinhopping step 4: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 5: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 6: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 7: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 8: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 9: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 10: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 11: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 12: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# found new global minimum on step 12 with function value -0.485677
# basinhopping step 13: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -0.485677 trial_f -0.485464 accepted False lowest_f -0.485677
# basinhopping step 15: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 16: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 17: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 18: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 19: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 20: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 21: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 22: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 23: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 24: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 25: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 26: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 27: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 28: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 29: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 30: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# warning: basinhopping: local minimization failure
# basinhopping step 31: f -0.485677 trial_f -0.21957 accepted False lowest_f -0.485677
# basinhopping step 32: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 33: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 34: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 35: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 36: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 37: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 38: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# warning: basinhopping: local minimization failure
# basinhopping step 39: f -0.485677 trial_f -0.485667 accepted False lowest_f -0.485677
# basinhopping step 40: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 41: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 42: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 43: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 44: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 45: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 46: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 47: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 48: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 49: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# adaptive stepsize: acceptance rate 0.920000 target 0.500000 new stepsize 0.555556 old stepsize 0.5
# basinhopping step 50: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 51: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 52: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 53: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 54: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 55: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 56: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 57: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 58: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 59: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 60: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 61: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 62: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 63: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 64: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 65: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 66: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 67: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 68: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 69: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 70: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 71: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 72: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# warning: basinhopping: local minimization failure
# basinhopping step 73: f -0.485677 trial_f -0.485677 accepted False lowest_f -0.485677
# basinhopping step 74: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 75: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 76: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 77: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 78: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 79: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 80: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 81: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 82: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 83: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 84: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 85: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 86: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 87: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 88: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 89: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 90: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# found new global minimum on step 90 with function value -0.485677
# basinhopping step 91: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# found new global minimum on step
f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 213: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 214: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 215: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 216: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 217: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 218: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 219: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 220: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 221: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 222: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 223: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# warning: basinhopping: local minimization failure
# basinhopping step 224: f -0.485677 trial_f -0.485677 accepted False lowest_f -0.485677
# basinhopping step 225: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 226: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 227: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 228: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 229: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 230: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 231: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 232: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 233: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 234: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 235: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 236: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# warning: basinhopping: local minimization failure
# basinhopping step 237: f -0.485677 trial_f -0.485231 accepted False lowest_f -0.485677
# basinhopping step 238: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 239: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 240: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 241: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 242: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 243: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 244: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 245: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 246: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 247: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 248: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# basinhopping step 249: f -0.485677 trial_f -0.485677 accepted True lowest_f -0.485677
# Trust region method:
# Final trust-constr success: True
# Exit status: 1
# Message: `gtol` termination condition is satisfied.
# Saved to results_data/trust_results_4D_20260304.pkl
# Trust-region results saved.
#
# Loading saved results...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/lo_optim2/lib/python3.11/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'outer_info'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 153
#     150         return None
#     151     return row["outer_info"][-1]["converged"]
# --> 153 df["outer_converged"] = df.apply(outer_converged, axis=1)
#     154 # print(df[df["method"] == "penalty"][["method", "seed_type", "outer_converged"]])
#     156 print(
#     157     df[df["method"] == "trust"][
#     158         ["method", "seed_type", "trust_success", "trust_status","trust_message"]
#     159     ]
#     160 )
#
# File ~/miniconda3/envs/lo_optim2/lib/python3.11/site-packages/pandas/core/frame.py:12419, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12405         raise ValueError(f"Unknown engine '{engine}'")
#   12407     op = frame_apply(
#   12408         self,
#   12409         func=func,
#    (...)  12417         kwargs=kwargs,
#   12418     )
# > 12419     return op.apply().__finalize__(self, method="apply")
#   12420 elif hasattr(engine, "__pandas_udf__"):
#   12421     if result_type is not None:
#
# File ~/miniconda3/envs/lo_optim2/lib/python3.11/site-packages/pandas/core/apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
#    1013     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# -> 1015 return self.apply_standard()
#
# File ~/miniconda3/envs/lo_optim2/lib/python3.11/site-packages/pandas/core/apply.py:1167, in FrameApply.apply_standard(self)
#    1165 def apply_standard(self):
#    1166     if self.engine == "python":
# -> 1167         results, res_index = self.apply_series_generator()
#    1168     else:
#    1169         results, res_index = self.apply_series_numba()
#
# File ~/miniconda3/envs/lo_optim2/lib/python3.11/site-packages/pandas/core/apply.py:1183, in FrameApply.apply_series_generator(self)
#    1180 results = {}
#    1182 for i, v in enumerate(series_gen):
# -> 1183     results[i] = self.func(v, *self.args, **self.kwargs)
#    1184     if isinstance(results[i], ABCSeries):
#    1185         # If we have a view on v, we need to make a copy because
#    1186         #  series_generator will swap out the underlying data
#    1187         results[i] = results[i].copy(deep=False)
#
# Cell In[1], line 149, in outer_converged(row)
#     148 def outer_converged(row):
# --> 149     if row["outer_info"] is None:
#     150         return None
#     151     return row["outer_info"][-1]["converged"]
#
# File ~/miniconda3/envs/lo_optim2/lib/python3.11/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~/miniconda3/envs/lo_optim2/lib/python3.11/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File ~/miniconda3/envs/lo_optim2/lib/python3.11/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'outer_info'

# %%
print(
    df[df["method"] == "trust"][
        ["method", "seed_type", "trust_success", "trust_status", "trust_message"]
    ]
)
# Out:
#   method seed_type  trust_success  trust_status  \
# 0  trust   optimal           True             1
# 1  trust    random           True             1
#
#                                 trust_message
# 0  `gtol` termination condition is satisfied.
# 1  `gtol` termination condition is satisfied.

# %%
plot_final_objective(df)
plot_constraint_violation(df)

# %%
plot_all_amplitudes(df_trust_loaded)
