# %%
import numpy as np
import matplotlib.pyplot as plt
import string
import os


plt.rcParams.update(
    {
        "font.size": 11,  # base font size (tick labels)
        "axes.labelsize": 13,  # axis labels
        "axes.titlesize": 13,
        "legend.fontsize": 11,
        "xtick.labelsize": 11,
        "ytick.labelsize": 11,
        "figure.dpi": 300,
    }
)

import jax.numpy as jnp
import jax

jax.config.update("jax_enable_x64", True)
jax.config.update("jax_default_device", jax.devices("cpu")[0])

# Import your optimization and plotting utilities
from optimization_core import (
    build_jsa_grid,
    penalty_continuation_grad_desc,
    load_results,
    to_complex,
    tensor_knapsack_bound,
)

# %%
# ---------------------------------------------------------
# 1. Experiment parameters
# ---------------------------------------------------------

# Parameters for the multivariate normal distribution
n = 60  # Number of points in the frequency grid nxnxn
d = 3  # Dimensionality of the problem
mean = jnp.zeros(d)  # Mean
x_lim = 4  # Limits in x and y ax0is for plotting

# # Sweep parameters
n_steps = 80  # Number of steps in the sweep
rho_values = jnp.linspace(
    -0.49, 0.99, n_steps
)  # rho_values is analogous to the correlation coefficients in the correlation matrix

# %%
sigma_list = []
eta_list = []
upper_bound_list = []

for i, rho_value in enumerate(rho_values):
    # ---------------------------------------------------------
    # 1. Export data
    # ---------------------------------------------------------
    filename = f"eigen_eval_results_{d}D_20260615_r_{rho_value:.2f}.pkl"
    if os.path.exists("results_data/" + filename):
        df, _, _ = load_results(filename)
        f_pen = df["optim_lo"]
        fun_pen = df["eta"]

        # ---------------------------------------------------------
        # 2. Build JSA grid and initial mode
        # ---------------------------------------------------------
        print("Building JSA grid...")
        _, jsa_data = build_jsa_grid(n, mean, rho_value, x_lim)
        jsa_flat = jnp.reshape(jsa_data, (n, n ** (d - 1)))
        u, s, vt = jax.scipy.linalg.svd(jsa_flat, full_matrices=False)

        bound, tau_opt, sigma, mu, v_caps = tensor_knapsack_bound(jsa_data)

        # Compute bounds
        upper_bound = bound
        sigma_1 = s[0]

        # Print results
        print(rf"Actual $\eta$: {fun_pen:.4f}")
        print(f"Actual sigma_1: {sigma_1:.4f}")
        print(f"Upper bound: {jnp.abs(upper_bound):.4f}")
        sigma_list.append(sigma_1)
        eta_list.append(fun_pen)
        upper_bound_list.append(upper_bound)
# Out:
# Building JSA grid...
# Actual $\eta$: 0.5384
# Actual sigma_1: 0.6240
# Upper bound: 0.5866
# Building JSA grid...
# Actual $\eta$: 0.6819
# Actual sigma_1: 0.7559
# Upper bound: 0.7117
# Building JSA grid...
# Actual $\eta$: 0.7549
# Actual sigma_1: 0.8175
# Upper bound: 0.7740
# Building JSA grid...
# Actual $\eta$: 0.8031
# Actual sigma_1: 0.8564
# Upper bound: 0.8164
# Building JSA grid...
# Actual $\eta$: 0.8384
# Actual sigma_1: 0.8839
# Upper bound: 0.8477
# Building JSA grid...
# Actual $\eta$: 0.8656
# Actual sigma_1: 0.9046
# Upper bound: 0.8724
# Building JSA grid...
# Actual $\eta$: 0.8874
# Actual sigma_1: 0.9209
# Upper bound: 0.8923
# Building JSA grid...
# Actual $\eta$: 0.9053
# Actual sigma_1: 0.9340
# Upper bound: 0.9088
# Building JSA grid...
# Actual $\eta$: 0.9202
# Actual sigma_1: 0.9447
# Upper bound: 0.9227
# Building JSA grid...
# Actual $\eta$: 0.9327
# Actual sigma_1: 0.9537
# Upper bound: 0.9346
# Building JSA grid...
# Actual $\eta$: 0.9434
# Actual sigma_1: 0.9612
# Upper bound: 0.9447
# Building JSA grid...
# Actual $\eta$: 0.9526
# Actual sigma_1: 0.9676
# Upper bound: 0.9535
# Building JSA grid...
# Actual $\eta$: 0.9604
# Actual sigma_1: 0.9731
# Upper bound: 0.9611
# Building JSA grid...
# Actual $\eta$: 0.9672
# Actual sigma_1: 0.9778
# Upper bound: 0.9677
# Building JSA grid...
# Actual $\eta$: 0.9731
# Actual sigma_1: 0.9818
# Upper bound: 0.9734
# Building JSA grid...
# Actual $\eta$: 0.9781
# Actual sigma_1: 0.9853
# Upper bound: 0.9783
# Building JSA grid...
# Actual $\eta$: 0.9825
# Actual sigma_1: 0.9882
# Upper bound: 0.9826
# Building JSA grid...
# Actual $\eta$: 0.9862
# Actual sigma_1: 0.9907
# Upper bound: 0.9863
# Building JSA grid...
# Actual $\eta$: 0.9894
# Actual sigma_1: 0.9929
# Upper bound: 0.9894
# Building JSA grid...
# Actual $\eta$: 0.9921
# Actual sigma_1: 0.9947
# Upper bound: 0.9921
# Building JSA grid...
# Actual $\eta$: 0.9943
# Actual sigma_1: 0.9962
# Upper bound: 0.9943
# Building JSA grid...
# Actual $\eta$: 0.9961
# Actual sigma_1: 0.9974
# Upper bound: 0.9961
# Building JSA grid...
# Actual $\eta$: 0.9975
# Actual sigma_1: 0.9983
# Upper bound: 0.9975
# Building JSA grid...
# Actual $\eta$: 0.9986
# Actual sigma_1: 0.9991
# Upper bound: 0.9986
# Building JSA grid...
# Actual $\eta$: 0.9994
# Actual sigma_1: 0.9996
# Upper bound: 0.9994
# Building JSA grid...
# Actual $\eta$: 0.9998
# Actual sigma_1: 0.9999
# Upper bound: 0.9998
# Building JSA grid...
# Actual $\eta$: 1.0000
# Actual sigma_1: 1.0000
# Upper bound: 1.0000
# Building JSA grid...
# Actual $\eta$: 0.9999
# Actual sigma_1: 0.9999
# Upper bound: 0.9999
# Building JSA grid...
# Actual $\eta$: 0.9996
# Actual sigma_1: 0.9997
# Upper bound: 0.9996
# Building JSA grid...
# Actual $\eta$: 0.9990
# Actual sigma_1: 0.9993
# Upper bound: 0.9990
# Building JSA grid...
# Actual $\eta$: 0.9982
# Actual sigma_1: 0.9988
# Upper bound: 0.9982
# Building JSA grid...
# Actual $\eta$: 0.9971
# Actual sigma_1: 0.9981
# Upper bound: 0.9972
# Building JSA grid...
# Actual $\eta$: 0.9959
# Actual sigma_1: 0.9973
# Upper bound: 0.9959
# Building JSA grid...
# Actual $\eta$: 0.9945
# Actual sigma_1: 0.9963
# Upper bound: 0.9945
# Building JSA grid...
# Actual $\eta$: 0.9928
# Actual sigma_1: 0.9952
# Upper bound: 0.9928
# Building JSA grid...
# Actual $\eta$: 0.9910
# Actual sigma_1: 0.9940
# Upper bound: 0.9910
# Building JSA grid...
# Actual $\eta$: 0.9889
# Actual sigma_1: 0.9926
# Upper bound: 0.9890
# Building JSA grid...
# Actual $\eta$: 0.9867
# Actual sigma_1: 0.9911
# Upper bound: 0.9868
# Building JSA grid...
# Actual $\eta$: 0.9843
# Actual sigma_1: 0.9894
# Upper bound: 0.9844
# Building JSA grid...
# Actual $\eta$: 0.9817
# Actual sigma_1: 0.9877
# Upper bound: 0.9818
# Building JSA grid...
# Actual $\eta$: 0.9789
# Actual sigma_1: 0.9858
# Upper bound: 0.9791
# Building JSA grid...
# Actual $\eta$: 0.9759
# Actual sigma_1: 0.9837
# Upper bound: 0.9762
# Building JSA grid...
# Actual $\eta$: 0.9727
# Actual sigma_1: 0.9816
# Upper bound: 0.9731
# Building JSA grid...
# Actual $\eta$: 0.9694
# Actual sigma_1: 0.9793
# Upper bound: 0.9698
# Building JSA grid...
# Actual $\eta$: 0.9658
# Actual sigma_1: 0.9768
# Upper bound: 0.9663
# Building JSA grid...
# Actual $\eta$: 0.9621
# Actual sigma_1: 0.9742
# Upper bound: 0.9627
# Building JSA grid...
# Actual $\eta$: 0.9581
# Actual sigma_1: 0.9715
# Upper bound: 0.9589
# Building JSA grid...
# Actual $\eta$: 0.9539
# Actual sigma_1: 0.9686
# Upper bound: 0.9548
# Building JSA grid...
# Actual $\eta$: 0.9496
# Actual sigma_1: 0.9655
# Upper bound: 0.9506
# Building JSA grid...
# Actual $\eta$: 0.9449
# Actual sigma_1: 0.9623
# Upper bound: 0.9462
# Building JSA grid...
# Actual $\eta$: 0.9401
# Actual sigma_1: 0.9589
# Upper bound: 0.9416
# Building JSA grid...
# Actual $\eta$: 0.9350
# Actual sigma_1: 0.9553
# Upper bound: 0.9367
# Building JSA grid...
# Actual $\eta$: 0.9297
# Actual sigma_1: 0.9515
# Upper bound: 0.9317
# Building JSA grid...
# Actual $\eta$: 0.9241
# Actual sigma_1: 0.9475
# Upper bound: 0.9264
# Building JSA grid...
# Actual $\eta$: 0.9182
# Actual sigma_1: 0.9433
# Upper bound: 0.9209
# Building JSA grid...
# Actual $\eta$: 0.9120
# Actual sigma_1: 0.9388
# Upper bound: 0.9151
# Building JSA grid...
# Actual $\eta$: 0.9055
# Actual sigma_1: 0.9341
# Upper bound: 0.9090
# Building JSA grid...
# Actual $\eta$: 0.8987
# Actual sigma_1: 0.9291
# Upper bound: 0.9027
# Building JSA grid...
# Actual $\eta$: 0.8915
# Actual sigma_1: 0.9238
# Upper bound: 0.8960
# Building JSA grid...
# Actual $\eta$: 0.8839
# Actual sigma_1: 0.9182
# Upper bound: 0.8890
# Building JSA grid...
# Actual $\eta$: 0.8759
# Actual sigma_1: 0.9123
# Upper bound: 0.8817
# Building JSA grid...
# Actual $\eta$: 0.8674
# Actual sigma_1: 0.9059
# Upper bound: 0.8740
# Building JSA grid...
# Actual $\eta$: 0.8584
# Actual sigma_1: 0.8992
# Upper bound: 0.8658
# Building JSA grid...
# Actual $\eta$: 0.8489
# Actual sigma_1: 0.8919
# Upper bound: 0.8572
# Building JSA grid...
# Actual $\eta$: 0.8387
# Actual sigma_1: 0.8842
# Upper bound: 0.8480
# Building JSA grid...
# Actual $\eta$: 0.8279
# Actual sigma_1: 0.8758
# Upper bound: 0.8386
# Building JSA grid...
# Actual $\eta$: 0.8163
# Actual sigma_1: 0.8667
# Upper bound: 0.8280
# Building JSA grid...
# Actual $\eta$: 0.8038
# Actual sigma_1: 0.8569
# Upper bound: 0.8172
# Building JSA grid...
# Actual $\eta$: 0.7903
# Actual sigma_1: 0.8462
# Upper bound: 0.8050
# Building JSA grid...
# Actual $\eta$: 0.7756
# Actual sigma_1: 0.8344
# Upper bound: 0.7924
# Building JSA grid...
# Actual $\eta$: 0.7596
# Actual sigma_1: 0.8214
# Upper bound: 0.7786
# Building JSA grid...
# Actual $\eta$: 0.7419
# Actual sigma_1: 0.8068
# Upper bound: 0.7629
# Building JSA grid...
# Actual $\eta$: 0.7222
# Actual sigma_1: 0.7904
# Upper bound: 0.7457
# Building JSA grid...
# Actual $\eta$: 0.7001
# Actual sigma_1: 0.7716
# Upper bound: 0.7265
# Building JSA grid...
# Actual $\eta$: 0.6747
# Actual sigma_1: 0.7496
# Upper bound: 0.7046
# Building JSA grid...
# Actual $\eta$: 0.6450
# Actual sigma_1: 0.7233
# Upper bound: 0.6789
# Building JSA grid...
# Actual $\eta$: 0.6091
# Actual sigma_1: 0.6908
# Upper bound: 0.6487
# Building JSA grid...
# Actual $\eta$: 0.5634
# Actual sigma_1: 0.6480
# Upper bound: 0.6091
# Building JSA grid...
# Actual $\eta$: 0.4997
# Actual sigma_1: 0.5858
# Upper bound: 0.5514
# Building JSA grid...
# Actual $\eta$: 0.3860
# Actual sigma_1: 0.4669
# Upper bound: 0.4407

# %%
r_values = rho_values
sigma = jnp.array(sigma_list)
actual_value = jnp.array(eta_list)
upper_bound = jnp.array(upper_bound_list)


# plt.figure(figsize=(7,5))
fig, ax = plt.subplots(figsize=(3.4, 2.6))

base_color = "tab:blue"  # choose any: "tab:red", "tab:green", etc.

# --- Shaded region between lower and upper ---
ax.fill_between(
    r_values,
    actual_value,
    upper_bound,
    color=base_color,
    alpha=0.2,
    label="Bounds region",
)

# --- Sigma 1 ---
ax.plot(
    r_values, sigma, color=base_color, alpha=0.6, linestyle="--", label=r"$\sigma_1$"
)

# --- Actual value ---
ax.plot(
    r_values,
    actual_value,
    color=base_color,
    alpha=1.0,
    linewidth=2.2,
    label=r"Optimal $\eta$",
)

# --- Upper bound ---
ax.plot(
    r_values,
    upper_bound,
    color=base_color,
    alpha=0.6,
    linestyle="-.",
    label=r"Upper bound",
)

# Internal tag for dimensionality (e.g., "3D")
ax.text(0.85, 0.85, "3D", transform=ax.transAxes, fontsize=14)

# Panel label (e.g., "(a)")
ax.text(-0.10, 1.1, "(a)", transform=ax.transAxes, fontsize=14)

ax.set_xlabel("r")
ax.set_ylabel("Homodyne overlap")
ax.grid(True, alpha=0.3)
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()

# %%
# plt.figure(figsize=(7,5))
fig, ax = plt.subplots(figsize=(3.4, 2.6))

base_color = "tab:blue"  # choose any: "tab:red", "tab:green", etc.

# --- Shaded region between lower and upper ---
ax.fill_between(
    r_values,
    actual_value,
    upper_bound,
    color=base_color,
    alpha=0.2,
    label="Bounds region",
)


# --- Actual value ---
ax.plot(
    r_values,
    actual_value,
    color=base_color,
    alpha=1.0,
    linewidth=2.2,
    label=r"Optimal $\eta$",
)

# --- Upper bound ---
ax.plot(
    r_values,
    upper_bound,
    color=base_color,
    alpha=0.6,
    linestyle="-.",
    label=r"Upper bound",
)

# Internal tag for dimensionality (e.g., "3D")
ax.text(0.85, 0.85, "3D", transform=ax.transAxes, fontsize=14)

# Panel label (e.g., "(a)")
ax.text(-0.10, 1.1, "(a)", transform=ax.transAxes, fontsize=14)

ax.set_xlabel("r")
ax.set_ylabel("Homodyne overlap")
ax.grid(True, alpha=0.3)
plt.legend(fontsize=8)
plt.tight_layout()
plt.savefig(f"knapsack_bound_gaussian_{d}D_plot.pdf", dpi=300, bbox_inches="tight")
plt.show()
