# %%
import numpy as np
import matplotlib.pyplot as plt
import string
import os


plt.rcParams.update(
    {
        "font.size": 11,  # base font size (tick labels)
        "axes.labelsize": 13,  # axis labels
        "axes.titlesize": 13,
        "legend.fontsize": 11,
        "xtick.labelsize": 11,
        "ytick.labelsize": 11,
        "figure.dpi": 300,
    }
)

import jax.numpy as jnp
import jax

jax.config.update("jax_enable_x64", True)
jax.config.update("jax_default_device", jax.devices("cpu")[0])

# Import your optimization and plotting utilities
from optimization_core import (
    build_jsa_grid,
    penalty_continuation_grad_desc,
    load_results,
    to_complex,
    tensor_knapsack_bound,
)

# %%
# ---------------------------------------------------------
# 1. Experiment parameters
# ---------------------------------------------------------

# Parameters for the multivariate normal distribution
n = 30  # Number of points in the frequency grid nxnxn
d = 5  # Dimensionality of the problem
mean = jnp.zeros(d)  # Mean
x_lim = 4  # Limits in x and y ax0is for plotting

# # Sweep parameters
n_steps = 68  # Number of steps in the sweep
rho_values = jnp.linspace(
    -0.24, 0.99, n_steps
)  # rho_values is analogous to the correlation coefficients in the correlation matrix

# %%
sigma_list = []
eta_list = []
upper_bound_list = []

for i, rho_value in enumerate(rho_values):
    # ---------------------------------------------------------
    # 1. Export data
    # ---------------------------------------------------------
    filename1 = f"eigen_eval_results_{d}D_20260615_r_{rho_value:.2f}.pkl"
    filename2 = f"eigen_eval_results_{d}D_20260616_r_{rho_value:.2f}.pkl"
    if os.path.exists("results_data/" + filename1) or os.path.exists(
        "results_data/" + filename2
    ):
        if os.path.exists("results_data/" + filename1):
            filename = filename1
        if os.path.exists("results_data/" + filename2):
            filename = filename2

        df, _, _ = load_results(filename)
        f_pen = df["optim_lo"]
        fun_pen = df["eta"]

        # ---------------------------------------------------------
        # 2. Build JSA grid and initial mode
        # ---------------------------------------------------------
        print("Building JSA grid...")
        _, jsa_data = build_jsa_grid(n, mean, rho_value, x_lim)
        jsa_flat = jnp.reshape(jsa_data, (n, n ** (d - 1)))
        u, s, vt = jax.scipy.linalg.svd(jsa_flat, full_matrices=False)

        bound, tau_opt, sigma, mu, v_caps = tensor_knapsack_bound(jsa_data)

        # Compute bounds
        upper_bound = bound
        sigma_1 = s[0]

        # Print results
        print(rf"Actual $\eta$: {fun_pen:.4f}")
        print(f"Actual sigma_1: {sigma_1:.4f}")
        print(f"Upper bound: {jnp.abs(upper_bound):.4f}")
        sigma_list.append(sigma_1)
        eta_list.append(fun_pen)
        upper_bound_list.append(upper_bound)
# Out:
# Building JSA grid...
# Actual $\eta$: 0.6223
# Actual sigma_1: 0.7697
# Upper bound: 0.6575
# Building JSA grid...
# Actual $\eta$: 0.7752
# Actual sigma_1: 0.8847
# Upper bound: 0.8055
# Building JSA grid...
# Actual $\eta$: 0.8509
# Actual sigma_1: 0.9290
# Upper bound: 0.8677
# Building JSA grid...
# Actual $\eta$: 0.8963
# Actual sigma_1: 0.9531
# Upper bound: 0.9054
# Building JSA grid...
# Actual $\eta$: 0.9264
# Actual sigma_1: 0.9682
# Upper bound: 0.9328
# Building JSA grid...
# Actual $\eta$: 0.9488
# Actual sigma_1: 0.9782
# Upper bound: 0.9526
# Building JSA grid...
# Actual $\eta$: 0.9647
# Actual sigma_1: 0.9853
# Upper bound: 0.9669
# Building JSA grid...
# Actual $\eta$: 0.9766
# Actual sigma_1: 0.9902
# Upper bound: 0.9774
# Building JSA grid...
# Actual $\eta$: 0.9848
# Actual sigma_1: 0.9938
# Upper bound: 0.9855
# Building JSA grid...
# Actual $\eta$: 0.9909
# Actual sigma_1: 0.9963
# Upper bound: 0.9912
# Building JSA grid...
# Actual $\eta$: 0.9953
# Actual sigma_1: 0.9981
# Upper bound: 0.9953
# Building JSA grid...
# Actual $\eta$: 0.9980
# Actual sigma_1: 0.9992
# Upper bound: 0.9980
# Building JSA grid...
# Actual $\eta$: 0.9995
# Actual sigma_1: 0.9998
# Upper bound: 0.9995
# Building JSA grid...
# Actual $\eta$: 1.0000
# Actual sigma_1: 1.0000
# Upper bound: 1.0000
# Building JSA grid...
# Actual $\eta$: 0.9997
# Actual sigma_1: 0.9999
# Upper bound: 0.9997
# Building JSA grid...
# Actual $\eta$: 0.9986
# Actual sigma_1: 0.9994
# Upper bound: 0.9986
# Building JSA grid...
# Actual $\eta$: 0.9969
# Actual sigma_1: 0.9987
# Upper bound: 0.9969
# Building JSA grid...
# Actual $\eta$: 0.9947
# Actual sigma_1: 0.9978
# Upper bound: 0.9948
# Building JSA grid...
# Actual $\eta$: 0.9920
# Actual sigma_1: 0.9967
# Upper bound: 0.9922
# Building JSA grid...
# Actual $\eta$: 0.9887
# Actual sigma_1: 0.9954
# Upper bound: 0.9892
# Building JSA grid...
# Actual $\eta$: 0.9852
# Actual sigma_1: 0.9940
# Upper bound: 0.9859
# Building JSA grid...
# Actual $\eta$: 0.9814
# Actual sigma_1: 0.9924
# Upper bound: 0.9822
# Building JSA grid...
# Actual $\eta$: 0.9772
# Actual sigma_1: 0.9906
# Upper bound: 0.9784
# Building JSA grid...
# Actual $\eta$: 0.9727
# Actual sigma_1: 0.9887
# Upper bound: 0.9742
# Building JSA grid...
# Actual $\eta$: 0.9678
# Actual sigma_1: 0.9867
# Upper bound: 0.9699
# Building JSA grid...
# Actual $\eta$: 0.9629
# Actual sigma_1: 0.9845
# Upper bound: 0.9653
# Building JSA grid...
# Actual $\eta$: 0.9577
# Actual sigma_1: 0.9822
# Upper bound: 0.9606
# Building JSA grid...
# Actual $\eta$: 0.9523
# Actual sigma_1: 0.9798
# Upper bound: 0.9557
# Building JSA grid...
# Actual $\eta$: 0.9466
# Actual sigma_1: 0.9772
# Upper bound: 0.9506
# Building JSA grid...
# Actual $\eta$: 0.9407
# Actual sigma_1: 0.9746
# Upper bound: 0.9454
# Building JSA grid...
# Actual $\eta$: 0.9347
# Actual sigma_1: 0.9718
# Upper bound: 0.9400
# Building JSA grid...
# Actual $\eta$: 0.9284
# Actual sigma_1: 0.9688
# Upper bound: 0.9345
# Building JSA grid...
# Actual $\eta$: 0.9219
# Actual sigma_1: 0.9657
# Upper bound: 0.9288
# Building JSA grid...
# Actual $\eta$: 0.9153
# Actual sigma_1: 0.9625
# Upper bound: 0.9230
# Building JSA grid...
# Actual $\eta$: 0.9084
# Actual sigma_1: 0.9592
# Upper bound: 0.9171
# Building JSA grid...
# Actual $\eta$: 0.9014
# Actual sigma_1: 0.9557
# Upper bound: 0.9109
# Building JSA grid...
# Actual $\eta$: 0.8941
# Actual sigma_1: 0.9520
# Upper bound: 0.9047
# Building JSA grid...
# Actual $\eta$: 0.8867
# Actual sigma_1: 0.9482
# Upper bound: 0.8983
# Building JSA grid...
# Actual $\eta$: 0.8790
# Actual sigma_1: 0.9442
# Upper bound: 0.8917
# Building JSA grid...
# Actual $\eta$: 0.8712
# Actual sigma_1: 0.9401
# Upper bound: 0.8850
# Building JSA grid...
# Actual $\eta$: 0.8631
# Actual sigma_1: 0.9357
# Upper bound: 0.8781
# Building JSA grid...
# Actual $\eta$: 0.8548
# Actual sigma_1: 0.9312
# Upper bound: 0.8710
# Building JSA grid...
# Actual $\eta$: 0.8462
# Actual sigma_1: 0.9264
# Upper bound: 0.8638
# Building JSA grid...
# Actual $\eta$: 0.8374
# Actual sigma_1: 0.9214
# Upper bound: 0.8563
# Building JSA grid...
# Actual $\eta$: 0.8284
# Actual sigma_1: 0.9162
# Upper bound: 0.8486
# Building JSA grid...
# Actual $\eta$: 0.8190
# Actual sigma_1: 0.9107
# Upper bound: 0.8407
# Building JSA grid...
# Actual $\eta$: 0.8093
# Actual sigma_1: 0.9049
# Upper bound: 0.8326
# Building JSA grid...
# Actual $\eta$: 0.7994
# Actual sigma_1: 0.8988
# Upper bound: 0.8241
# Building JSA grid...
# Actual $\eta$: 0.7890
# Actual sigma_1: 0.8923
# Upper bound: 0.8154
# Building JSA grid...
# Actual $\eta$: 0.7783
# Actual sigma_1: 0.8855
# Upper bound: 0.8064
# Building JSA grid...
# Actual $\eta$: 0.7671
# Actual sigma_1: 0.8782
# Upper bound: 0.7970
# Building JSA grid...
# Actual $\eta$: 0.7555
# Actual sigma_1: 0.8705
# Upper bound: 0.7873
# Building JSA grid...
# Actual $\eta$: 0.7434
# Actual sigma_1: 0.8623
# Upper bound: 0.7771
# Building JSA grid...
# Actual $\eta$: 0.7307
# Actual sigma_1: 0.8535
# Upper bound: 0.7664
# Building JSA grid...
# Actual $\eta$: 0.7174
# Actual sigma_1: 0.8440
# Upper bound: 0.7552
# Building JSA grid...
# Actual $\eta$: 0.7033
# Actual sigma_1: 0.8338
# Upper bound: 0.7433
# Building JSA grid...
# Actual $\eta$: 0.6884
# Actual sigma_1: 0.8227
# Upper bound: 0.7307
# Building JSA grid...
# Actual $\eta$: 0.6726
# Actual sigma_1: 0.8105
# Upper bound: 0.7173
# Building JSA grid...
# Actual $\eta$: 0.6556
# Actual sigma_1: 0.7971
# Upper bound: 0.7028
# Building JSA grid...
# Actual $\eta$: 0.6374
# Actual sigma_1: 0.7823
# Upper bound: 0.6872
# Building JSA grid...
# Actual $\eta$: 0.6174
# Actual sigma_1: 0.7655
# Upper bound: 0.6701
# Building JSA grid...
# Actual $\eta$: 0.5955
# Actual sigma_1: 0.7465
# Upper bound: 0.6513
# Building JSA grid...
# Actual $\eta$: 0.5710
# Actual sigma_1: 0.7244
# Upper bound: 0.6300
# Building JSA grid...
# Actual $\eta$: 0.5429
# Actual sigma_1: 0.6981
# Upper bound: 0.6051
# Building JSA grid...
# Actual $\eta$: 0.5099
# Actual sigma_1: 0.6658
# Upper bound: 0.5756
# Building JSA grid...
# Actual $\eta$: 0.4689
# Actual sigma_1: 0.6236
# Upper bound: 0.5383
# Building JSA grid...
# Actual $\eta$: 0.4073
# Actual sigma_1: 0.5614
# Upper bound: 0.4804
# Building JSA grid...
# Actual $\eta$: 0.1845
# Actual sigma_1: 0.4165
# Upper bound: 0.3915

# %%
r_values = rho_values
sigma = jnp.array(sigma_list)
actual_value = jnp.array(eta_list)
upper_bound = jnp.array(upper_bound_list)


# plt.figure(figsize=(7,5))
fig, ax = plt.subplots(figsize=(3.4, 2.6))

base_color = "tab:green"  # choose any: "tab:red", "tab:green", etc.

# --- Shaded region between lower and upper ---
ax.fill_between(
    r_values,
    actual_value,
    upper_bound,
    color=base_color,
    alpha=0.2,
    label="Bounds region",
)

# --- Sigma 1 ---
ax.plot(
    r_values, sigma, color=base_color, alpha=0.6, linestyle="--", label=r"$\sigma_1$"
)

# --- Actual value ---
ax.plot(
    r_values,
    actual_value,
    color=base_color,
    alpha=1.0,
    linewidth=2.2,
    label=r"Optimal $\eta$",
)

# --- Upper bound ---
ax.plot(
    r_values,
    upper_bound,
    color=base_color,
    alpha=0.6,
    linestyle="-.",
    label=r"Upper bound",
)

# Internal tag for dimensionality (e.g., "3D")
ax.text(0.85, 0.85, "5D", transform=ax.transAxes, fontsize=14)

# Panel label (e.g., "(a)")
ax.text(-0.10, 1.1, "(c)", transform=ax.transAxes, fontsize=14)

ax.set_xlabel("r")
ax.set_ylabel("Homodyne overlap")
ax.grid(True, alpha=0.3)
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()

# %%
# plt.figure(figsize=(7,5))
fig, ax = plt.subplots(figsize=(3.4, 2.6))

base_color = "tab:green"  # choose any: "tab:red", "tab:green", etc.

# --- Shaded region between lower and upper ---
ax.fill_between(
    r_values,
    actual_value,
    upper_bound,
    color=base_color,
    alpha=0.2,
    label="Bounds region",
)


# --- Actual value ---
ax.plot(
    r_values,
    actual_value,
    color=base_color,
    alpha=1.0,
    linewidth=2.2,
    label=r"Optimal $\eta$",
)

# --- Upper bound ---
ax.plot(
    r_values,
    upper_bound,
    color=base_color,
    alpha=0.6,
    linestyle="-.",
    label=r"Upper bound",
)

# Internal tag for dimensionality (e.g., "3D")
ax.text(0.85, 0.85, "5D", transform=ax.transAxes, fontsize=14)

# Panel label (e.g., "(a)")
ax.text(-0.10, 1.1, "(c)", transform=ax.transAxes, fontsize=14)

ax.set_xlabel("r")
ax.set_ylabel("Homodyne overlap")
ax.grid(True, alpha=0.3)
plt.legend(fontsize=8)
plt.tight_layout()
plt.savefig(f"knapsack_bound_gaussian_{d}D_plot.pdf", dpi=300, bbox_inches="tight")
plt.show()
